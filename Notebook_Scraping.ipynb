# %% [markdown]
# **Sentimen Analisis Review Aplikasi Duolingo di Playstore**
#
# Pada proyek ini, akan dilakukan analisis sentimen terhadap ulasan dan pendapat pengguna terkait aplikasi "Duolingo" di Play Store. Analisis sentimen akan membantu kita untuk memahami bagaimana pengguna merasakan dan mengungkapkan pandangan mereka terhadap aplikasi ini.
#
# Dengan menggunakan berbagai teknik pemrosesan teks dan algoritma machine learning, kita akan mencoba mengidentifikasi apakah ulasan pengguna terhadap aplikasi "Duolingo" cenderung positif, negatif, atau netral. Hasil analisis sentimen ini dapat memberikan wawasan berharga kepada pengembang aplikasi untuk meningkatkan pengalaman pengguna.

# %% [markdown]
# # **Import Library**

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.1 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd  # Pandas untuk manipulasi dan analisis data
import csv

# %% [markdown]
# # **Scraping Data**

# %%
# Mengambil semua ulasan dari aplikasi dengan ID 'com.bd.nproject' di Google Play Store.
scrapreview = reviews_all(
    'com.bd.nproject',     # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=1000             # Jumlah maksimum ulasan yang ingin diambil
)

# %%
with open('Dataset_Scraping.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  4041b377-b5dd-4f58-8610-80f0502e5b8f  Pengguna Google
# 1  3591ad33-9acb-45ef-90de-9d1a400d80ea  Pengguna Google
# 2  132838cf-0fda-41f6-bb99-d5acb53f9c18  Pengguna Google
# 3  9b500c79-f584-4ffd-aa84-ddd953f30bf1  Pengguna Google
# 4  3b102fe2-e915-48e5-b15f-393aa7cfd580  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasi yang menarik, kita bisa berbagi cerit...      5           1111
# 1  kasih 4dlu klo bagus kaya tiktok dan waveful n...      4             12
# 2  Balikin akun aku yg lama. Terserah kalian mau ...      1             85
# 3  Sebelumnya suka dengan aplikasi ini, banyak in...      1             75
# 4  Kecewa ada kebijakan baru login harus pakai ti...      4             36
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                7.9.5 2025-01-30 12:22:40         None       NaT      7.9.5
# 1                8.4.0 2025-03-30 11:36:49         None       NaT      8.4.0
# 2                7.9.5 2025-02-10 13:17:23         None       NaT      7.9.5
# 3                7.9.5 2025-01-29 18:03:14         None       NaT      7.9.5
# 4                8.1.5 2025-03-03 21:09:00         None       NaT      8.1.5

# %% [markdown]
# # **Simpan Dataset dalam Format .csv**

# %%
app_reviews_df.to_csv('Dataset_Scraping.csv', index=False)
